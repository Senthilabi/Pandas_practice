# %%
import pandas as pd

# %%
#xl2=data_load(file2)
xl2=pd.ExcelFile('Data_Dashboard_Extended.xlsx')
xl2sheets=xl2.sheet_names
file2='Data_Dashboard_Extended.xlsx'
techdf=pd.read_excel(file2,sheet_name=xl2sheets[0],header=[0,1])
tactdf=pd.read_excel(file2,sheet_name=xl2sheets[1],header=[0,1])
techcol=techdf.columns.get_level_values
c=list(tactdf.columns.get_level_values(0))

# %%
tactdf.set_index('Unnamed: 0_level_0', inplace=True)

# %%
tactdf.index
# Out:
# Index([        ('Jack Clarke',),               ('Bruma',),
#        ('Philip Zinckernagel',),     ('Andreas S Olsen',),
#                 ('Baris Atik',),        ('Fabian Reese',),
#              ('Gaëtan Perrin',),         ('Désiré Doué',),
#               ('Antonio Nusa',)],
#       dtype='object', name='Unnamed: 0_level_0')

# %%
tactdf.index[0]
# Out:
# ('Jack Clarke',)

# %%
print(c.unique())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(c.unique())
#
# AttributeError: 'list' object has no attribute 'unique'

# %%
techdf.head()
# Out:
#     Unnamed: 0_level_0 Attacking                                       ...  \
#                 Player         G   A G+A nPGs PKs M PKs A  YC  RC  xG  ...
# 0          Jack Clarke        86  65  82   75    94    92  44  57  77  ...
# 1                Bruma        37  83  62   44    33    32  19  57  78  ...
# 2  Philip Zinckernagel        78  86  86   78    76    70  78  57  83  ...
# 3      Andreas S Olsen        89  77  90   90    84    87  63  57  89  ...
# 4           Baris Atik        44  86  70   42    69    64   4  57  39  ...
#
#   Miscellenaeous                                                              \
#          Crosses Intercepts Tackls W PKs W PKs C Ogs Ball Recovers Aerials W
# 0             57         49       86    99    54  51            43        47
# 1              5          2       66    31    54  51            83         5
# 2             79         48       66    95    54  51            31        52
# 3             72         79       45    31    54  51            88        29
# 4             56         19        8    31    54  51            14        45
#
#
#   Aerials L % Aerials W
# 0        59          54
# 1        85           7
# 2        53          56
# 3        78          49
# 4        35          27
#
# [5 rows x 136 columns]

# %%
techdf.set_index('Unnamed: 0_level_0', inplace=True)

# %%
techdf.index
# Out:
# Index([        ('Jack Clarke',),               ('Bruma',),
#        ('Philip Zinckernagel',),     ('Andreas S Olsen',),
#                 ('Baris Atik',),        ('Fabian Reese',),
#              ('Gaëtan Perrin',),         ('Désiré Doué',),
#               ('Antonio Nusa',)],
#       dtype='object', name='Unnamed: 0_level_0')

# %%
print(type(techdf.index[0]))
# Out:
# <class 'tuple'>

# %%
techdf.index = techdf.index.map(lambda x: x[0])

# %%
bar=techdf.loc['Bruma']['Attacking']
bar_y=bar.index

# %%
bar_x=list(bar)

# %%
import plotly.express as px
import plotly.graph_objects as go
import random
import numpy as np

# %%
def bar_chart(series,name):
    fig = go.Figure()
    fig.add_trace(go.Bar(
        y=series.index,
        x=list(series),
        name=name,
        orientation='h',

    ))
    fig.update_layout(barmode='stack')
    return fig

# %%
fig=go.Figure
fig.add_trace(go.Bar(
    x=['A','B','C','D'],
    y=np.random.randint(50,100,4),
    marker=dict(
        color='rgba(50, 171, 96, 0.6)',
        line=dict(
            color='rgba(50, 171, 96, 1.0)',
            width=1),
    ),
    name='Household savings, percentage of household disposable income',
    orientation='h',
), 1, 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 fig=go.Figure
# ----> 2 fig.add_trace(go.Bar(
#       3     x=['A','B','C','D'],
#       4     y=np.random.randint(50,100,4),
#       5     marker=dict(
#       6         color='rgba(50, 171, 96, 0.6)',
#       7         line=dict(
#       8             color='rgba(50, 171, 96, 1.0)',
#       9             width=1),
#      10     ),
#      11     name='Household savings, percentage of household disposable income',
#      12     orientation='h',
#      13 ), 1, 1)
#
# File C:\ProgramData\anaconda3\lib\site-packages\plotly\graph_objs\_figure.py:865, in Figure.add_trace(self, trace, row, col, secondary_y, exclude_empty_subplots)
#     790 def add_trace(
#     791     self, trace, row=None, col=None, secondary_y=None, exclude_empty_subplots=False
#     792 ) -> "Figure":
#     793     """
#     794
#     795     Add a trace to the figure
#    (...)
#     863
#     864     """
# --> 865     return super(Figure, self).add_trace(
#     866         trace, row, col, secondary_y, exclude_empty_subplots
#     867     )
#
# TypeError: super(type, obj): obj must be an instance or subtype of type

# %%
techdf.loc['Bruma':'Attacking']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Attacking'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 techdf.loc['Bruma':'Attacking']
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexing.py:1290, in _LocIndexer._getitem_axis(self, key, axis)
#    1288 if isinstance(key, slice):
#    1289     self._validate_key(key, axis)
# -> 1290     return self._get_slice_axis(key, axis=axis)
#    1291 elif com.is_bool_indexer(key):
#    1292     return self._getbool_axis(key, axis=axis)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexing.py:1324, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1321     return obj.copy(deep=False)
#    1323 labels = obj._get_axis(axis)
# -> 1324 indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1326 if isinstance(indexer, slice):
#    1327     return self.obj._slice(indexer, axis=axis)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6559, in Index.slice_indexer(self, start, end, step, kind)
#    6516 """
#    6517 Compute the slice indexer for input labels and step.
#    6518
#    (...)
#    6555 slice(1, 3, None)
#    6556 """
#    6557 self._deprecated_arg(kind, "kind", "slice_indexer")
# -> 6559 start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6561 # return a slice
#    6562 if not is_scalar(start_slice):
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6773, in Index.slice_locs(self, start, end, step, kind)
#    6771 end_slice = None
#    6772 if end is not None:
# -> 6773     end_slice = self.get_slice_bound(end, "right")
#    6774 if end_slice is None:
#    6775     end_slice = len(self)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6686, in Index.get_slice_bound(self, label, side, kind)
#    6683         return self._searchsorted_monotonic(label, side)
#    6684     except ValueError:
#    6685         # raise the original KeyError
# -> 6686         raise err
#    6688 if isinstance(slc, np.ndarray):
#    6689     # get_loc may return a boolean array, which
#    6690     # is OK as long as they are representable by a slice.
#    6691     assert is_bool_dtype(slc.dtype)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6680, in Index.get_slice_bound(self, label, side, kind)
#    6678 # we need to look up the label
#    6679 try:
# -> 6680     slc = self.get_loc(label)
#    6681 except KeyError as err:
#    6682     try:
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Attacking'

# %%
techdf
# Out:
#                     Attacking                                            ...  \
#                             G   A G+A nPGs PKs M PKs A  YC  RC  xG nPxG  ...
# Unnamed: 0_level_0                                                       ...
# Jack Clarke                86  65  82   75    94    92  44  57  77   50  ...
# Bruma                      37  83  62   44    33    32  19  57  78   87  ...
# Philip Zinckernagel        78  86  86   78    76    70  78  57  83   84  ...
# Andreas S Olsen            89  77  90   90    84    87  63  57  89   84  ...
# Baris Atik                 44  86  70   42    69    64   4  57  39   39  ...
# Fabian Reese               76  96  93   69    84    80  92  57  51   38  ...
# Gaëtan Perrin              58  85  75   63    34    32  91  57  28   37  ...
# Désiré Doué                34  58  38   40    35    33  39  58  14   20  ...
# Antonio Nusa               82  66  79   89    34    32  97  57  73   83  ...
#
#                     Miscellenaeous                                      \
#                            Crosses Intercepts Tackls W PKs W PKs C Ogs
# Unnamed: 0_level_0
# Jack Clarke                     57         49       86    99    54  51
# Bruma                            5          2       66    31    54  51
# Philip Zinckernagel             79         48       66    95    54  51
# Andreas S Olsen                 72         79       45    31    54  51
# Baris Atik                      56         19        8    31    54  51
# Fabian Reese                    95         67       34    64    54  51
# Gaëtan Perrin                   83         73       25    31    55  51
# Désiré Doué                     60         97       93    89    57  51
# Antonio Nusa                    61         59       86    31    55  51
#
#
#                     Ball Recovers Aerials W Aerials L % Aerials W
# Unnamed: 0_level_0
# Jack Clarke                    43        47        59          54
# Bruma                          83         5        85           7
# Philip Zinckernagel            31        52        53          56
# Andreas S Olsen                88        29        78          49
# Baris Atik                     14        45        35          27
# Fabian Reese                   55        62        97          99
# Gaëtan Perrin                  34         7        65           6
# Désiré Doué                    85         8        62           4
# Antonio Nusa                   83        51        41          40
#
# [9 rows x 135 columns]

# %%
techdf.columns.values
# Out:
# array([('Attacking', 'G'), ('Attacking', 'A'), ('Attacking', 'G+A'),
#        ('Attacking', 'nPGs'), ('Attacking', 'PKs M'),
#        ('Attacking', 'PKs A'), ('Attacking', 'YC'), ('Attacking', 'RC'),
#        ('Attacking', 'xG'), ('Attacking', 'nPxG'), ('Attacking', 'xAG'),
#        ('Attacking', 'nPxG + xAG'), ('Attacking', 'Prog Carries'),
#        ('Attacking', 'Prog Pass'), ('Attacking', 'Prog Pass Rec'),
#        ('Shooting', 'G'), ('Shooting', 'Sh'), ('Shooting', 'ShOT'),
#        ('Shooting', 'ShOT%'), ('Shooting', 'G/ Sh'),
#        ('Shooting', 'G/ShOT'), ('Shooting', 'Avg Sh D'),
#        ('Shooting', 'ShFK'), ('Shooting', 'PkM'), ('Shooting', 'PkA'),
#        ('Shooting', 'xG'), ('Shooting', 'nPxG'), ('Shooting', 'npxG/Sh'),
#        ('Shooting', 'G - xG'), ('Shooting', 'nPG-nPxG'),
#        ('Passing', 'Pass C'), ('Passing', 'Pass A'),
#        ('Passing', 'Pass C%'), ('Passing', 'Total Pass D'),
#        ('Passing', 'Prog Pass D'), ('Passing', 'Pass C(S)'),
#        ('Passing', 'Pass A(S)'), ('Passing', 'Pass C(S)%'),
#        ('Passing', 'Pass C(M)'), ('Passing', 'Pass A(M)'),
#        ('Passing', 'Pass C(M)%'), ('Passing', 'Pass C(L)'),
#        ('Passing', 'Pass A(L)'), ('Passing', 'Pass C(L)%'),
#        ('Passing', 'A'), ('Passing', 'xAG'), ('Passing', 'xA'),
#        ('Passing', 'Key Passes'), ('Passing', 'Passes to Final 3rd'),
#        ('Passing', 'Passes to PA'), ('Passing', 'Cross to PA'),
#        ('Passing', 'Prog Pass'), ('Pass Types', 'Pass A'),
#        ('Pass Types', 'Live B Pass'), ('Pass Types', 'Dead B Pass'),
#        ('Pass Types', 'Pass from FK'), ('Pass Types', 'Through Balls'),
#        ('Pass Types', 'Switches'), ('Pass Types', 'Crosses'),
#        ('Pass Types', 'Throw Ins '), ('Pass Types', 'CKs'),
#        ('Pass Types', 'Insw CK'), ('Pass Types', 'Outsw CK'),
#        ('Pass Types', 'Str CK'), ('Pass Types', 'Pass C'),
#        ('Pass Types', 'Pass Off'), ('Pass Types', 'Pass Block'),
#        ('Shot Creation Actions', 'SCA'),
#        ('Shot Creation Actions', 'SCA (Live B P)'),
#        ('Shot Creation Actions', 'SCA (Dead B P)'),
#        ('Shot Creation Actions', 'SCA (Take-On)'),
#        ('Shot Creation Actions', 'SCA (Sh)'),
#        ('Shot Creation Actions', 'SCA (Fouls Drawn)'),
#        ('Shot Creation Actions', 'SCA (Def)'),
#        ('Goal Creation Actions', 'GCA'),
#        ('Goal Creation Actions', 'GCA (Live B P)'),
#        ('Goal Creation Actions', 'GCA (Dead B P)'),
#        ('Goal Creation Actions', 'GCA (Take-On)'),
#        ('Goal Creation Actions', 'GCA (Sh)'),
#        ('Goal Creation Actions', 'GCA (Fouls Drawn)'),
#        ('Goal Creation Actions', 'GCA (Def)'), ('Defense', 'Tackles'),
#        ('Defense', 'Tackles Won'), ('Defense', 'Tackles (Def)'),
#        ('Defense', 'Tackles (Mid)'), ('Defense', 'Tackles (Att)'),
#        ('Defense', 'Dribblers Tackled'), ('Defense', 'Dribbles Chall'),
#        ('Defense', '% of Dribb Tackled'), ('Defense', 'Chall Lost'),
#        ('Defense', 'Blocks'), ('Defense', 'Sh Block'),
#        ('Defense', 'Pass Block'), ('Defense', 'Intercepts'),
#        ('Defense', 'Tkl+Int'), ('Defense', 'Clearance'),
#        ('Defense', 'Errors'), ('Possession', 'Touches'),
#        ('Possession', 'Touches (Def Pen)'),
#        ('Possession', 'Touches (Def)'), ('Possession', 'Touches (Mid)'),
#        ('Possession', 'Touches (Att)'), ('Possession', 'Touches (Att).1'),
#        ('Possession', 'Touches (Live-B)'), ('Possession', 'Take-Ons A'),
#        ('Possession', 'Successful Take-Ons'),
#        ('Possession', 'Successful Take-On %'),
#        ('Possession', ' Tackl During Take-On'),
#        ('Possession', 'Tack D TONS %'), ('Possession', 'Carries'),
#        ('Possession', 'Total Carry D'), ('Possession', 'Prog Carry D'),
#        ('Possession', 'Prog Carry'),
#        ('Possession', 'Carries to Final Third'),
#        ('Possession', 'Carries to PA'), ('Possession', 'Miscontrols'),
#        ('Possession', 'Dispossessed'), ('Possession', 'Passes Rec'),
#        ('Possession', 'Prog Pass Rec'), ('Miscellenaeous', 'YC'),
#        ('Miscellenaeous', 'RC'), ('Miscellenaeous', '2nd YC'),
#        ('Miscellenaeous', 'Fouls C'), ('Miscellenaeous', 'Fouls D'),
#        ('Miscellenaeous', 'Off'), ('Miscellenaeous', 'Crosses'),
#        ('Miscellenaeous', 'Intercepts'), ('Miscellenaeous', 'Tackls W'),
#        ('Miscellenaeous', 'PKs W'), ('Miscellenaeous', 'PKs C'),
#        ('Miscellenaeous', 'Ogs'), ('Miscellenaeous', 'Ball Recovers'),
#        ('Miscellenaeous', 'Aerials W'), ('Miscellenaeous', 'Aerials L'),
#        ('Miscellenaeous', '% Aerials W')], dtype=object)

# %%
techdf[techdf['Player']=='Jack Clarke']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Player'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 techdf[techdf['Player']=='Jack Clarke']
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:3806, in DataFrame.__getitem__(self, key)
#    3804 if is_single_key:
#    3805     if self.columns.nlevels > 1:
# -> 3806         return self._getitem_multilevel(key)
#    3807     indexer = self.columns.get_loc(key)
#    3808     if is_integer(indexer):
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:3857, in DataFrame._getitem_multilevel(self, key)
#    3855 def _getitem_multilevel(self, key):
#    3856     # self.columns is a MultiIndex
# -> 3857     loc = self.columns.get_loc(key)
#    3858     if isinstance(loc, (slice, np.ndarray)):
#    3859         new_columns = self.columns[loc]
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\multi.py:2916, in MultiIndex.get_loc(self, key, method)
#    2913     return mask
#    2915 if not isinstance(key, tuple):
# -> 2916     loc = self._get_level_indexer(key, level=0)
#    2917     return _maybe_to_slice(loc)
#    2919 keylen = len(key)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\multi.py:3263, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3259         return slice(i, j, step)
#    3261 else:
# -> 3263     idx = self._get_loc_single_level_index(level_index, key)
#    3265     if level > 0 or self._lexsort_depth == 0:
#    3266         # Desired level is not sorted
#    3267         if isinstance(idx, slice):
#    3268             # test_get_loc_partial_timestamp_multiindex
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\multi.py:2849, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2847     return -1
#    2848 else:
# -> 2849     return level_index.get_loc(key)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Player'

# %%
#Text Row
#c1,c2,=st.columns(2)
#c1,c11,c2,c21,c3,c31=st.columns(6)
t_c11=list(text_area_data.columns)[0]
t_v11=text_area_data.iloc[0,0]
#c11.metric(t_c11,t_v11)
#c1.subheader(t_c11+'  :')
#c11.subheader(t_v11)
t_c12=list(text_area_data.columns)[1]
t_v12=text_area_data.iloc[0,1]
#c12.metric(t_c12,t_v12)

#c2.subheader(t_c12+':')
#c21.subheader(t_v12)
#c3.subheader('Score  :')
#c31.subheader(circle_score)

r1heading=[t_c11,t_c12,'Score']
r1value=[t_v11,t_v12,circle_score]
dic1={x:y for x , y in zip(r1heading,r1value)}
sdf1=pd.DataFrame(dic1,columns=dic1.keys(),index=['I'])
st.dataframe(sdf1)

#    st.markdown('<div class="custom-column">', unsafe_allow_html=True)
    
#   st.markdown('</div>', unsafe_allow_html=True)

#Text Area second row
c0,c1,c2,c3,c4,c5,c6 = st.columns([6,3,3,3,3,3,3])


t_c3=list(text_area_data.columns)[2]
t_v31=text_area_data.iloc[0,2]
t_v32=text_area_data.iloc[1,2]
t_v33=text_area_data.iloc[2,2]
t_v34=text_area_data.iloc[3,2]
t_v35=text_area_data.iloc[4,2]
t_v36=text_area_data.iloc[5,2]
t3=text_area_data[t_c3]
#c0.subheader(t_c3)
c1.write(t_v31)
c2.write(t_v32)
c3.write(t_v33)
c4.write(t_v34)
c5.write(t_v35)
c6.write(t_v36)

#c0.metric('',t_c3)

#c2.write('',t_v31)
#c2.write('',t_v32)
#c3.write('',t_v33)
#c4.write('',t_v34)
#c5.write('',t_v35)
#c6.write('',t_v36)
st.dataframe(t3.T )
c0,c1,c2,c3,c4,c5,c6 = st.columns([6,3,3,3,3,3,3])


t_c3=list(text_area_data.columns)[3]
t_v31=text_area_data.iloc[0,3]
t_v32=text_area_data.iloc[1,3]
t_v33=text_area_data.iloc[2,3]
t_v34=text_area_data.iloc[3,3]
t_v35=text_area_data.iloc[4,3]
t_v36=text_area_data.iloc[5,3]

c0.subheader(t_c3)
c1.write(t_v31)
c2.write(t_v32)
c3.write(t_v33)
c4.write(t_v34)
c5.write(t_v35)
c6.write(t_v36)
#code for the h bar plot
# Sample data
categories = ['Category 1', 'Category 2', 'Category 3','Category 4', 'Category 5']

def bar_diagram(categories):
    #categories = ['Category 1', 'Category 2', 'Category 3','Category 4', 'Category 5']
    values = [100/len(categories) for x in range(len(categories))]

    # Normalize the values to represent percentages
    total = sum(values)
    percentages = [value / total * 100 for value in values]

    # Define colors for each category
    colors = ['#636EFA', '#EF553B', '#00CC96','#FF5599','#22EEAA',
                '#234567', '#0044BB'                   ]

    # Create the figure
    fig = go.Figure()

    # Add the bar trace for each category
    for category, percentage, color in zip(categories, percentages, colors):
        fig.add_trace(go.Bar(
        y=[''],  # Single bar
        x=[percentage],  # The width of the segment
        name=category,
        orientation='h',
        text=f"{category}", #{percentage:.1f}%",  # Text inside the bar
        textposition='inside',
        textfont_size=20,
        
        marker=dict(color=color)  # Set the color for each segment
    ))

    # Update layout
    fig.update_layout(
    #margin=dict(t=40,b=40),
    autosize=False,
    #    minreducedwidth=250,
    #    minreducedheight=250,
    width=600,
    height=250,
    title='',#'100% Stacked Horizontal Bar Chart',
    xaxis_title='',#'Percentage',
    yaxis_title='',
    barmode='stack',
    xaxis=dict(range=[0, 100]),  # Ensure the x-axis ranges from 0 to 100
    showlegend=False
    )
    fig.update_xaxes(showticklabels=False)
    fig.update_yaxes(showline=False, showticklabels=False,linecolor='white')
    config ={'displayModeBar': False}

    return fig
#fig.update_yaxes(showline=False)
bar1=bar_diagram(categories)
# Display the chart
st.plotly_chart(bar1)
st.plotly_chart(bar1)

#code for hbar plot ends here
